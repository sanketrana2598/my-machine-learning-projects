# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('revenue_prediction (3).csv')

# %%
df
# Out:
#      Id                          Name Franchise       Category       City  \
# 0   101            HungryHowie'sPizza       Yes        Mexican  Bengaluru
# 1   102          CharleysPhillySteaks        No    Varied Menu   Gurugram
# 2   103                        Chuy's       Yes        Chicken       Pune
# 3   104                   O'Charley's       Yes  Italian/Pizza     Mumbai
# 4   105                 PolloTropical       Yes          Pizza      Noida
# ..  ...                           ...       ...            ...        ...
# 95  196              Wetzel'sPretzels        No  Italian/Pizza  Bengaluru
# 96  197  LaMadeleineCountryFrenchCafe       Yes    Varied Menu  Bengaluru
# 97  198                    Giordano's       Yes    Varied Menu   Gurugram
# 98  199     IslandsFineBurgers&Drinks       Yes     Sports Bar       Pune
# 99  200           Mimi'sBistro&Bakery        No            BBQ     Mumbai
#
#     No_Of_Item  Order_Placed  Revenue
# 0           55           5.5  5953753
# 1           72           6.8  7223131
# 2           25           1.9  2555379
# 3           18           2.5  2175511
# 4           48           4.2  4816715
# ..         ...           ...      ...
# 95          19           1.1  1270499
# 96          75           6.3  6412623
# 97          77           6.2  6694797
# 98          25           2.1  2344689
# 99          50           4.4  4567678
#
# [100 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            100 non-null    int64
#  1   Name          100 non-null    object
#  2   Franchise     100 non-null    object
#  3   Category      100 non-null    object
#  4   City          100 non-null    object
#  5   No_Of_Item    100 non-null    int64
#  6   Order_Placed  100 non-null    float64
#  7   Revenue       100 non-null    int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 6.4+ KB

# %%
df.isnull().sum()
# Out:
# Id              0
# Name            0
# Franchise       0
# Category        0
# City            0
# No_Of_Item      0
# Order_Placed    0
# Revenue         0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for i in df.columns:
   if df[i].dtype == 'object':
      df[i] = le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            100 non-null    int64
#  1   Name          100 non-null    int32
#  2   Franchise     100 non-null    int32
#  3   Category      100 non-null    int32
#  4   City          100 non-null    int32
#  5   No_Of_Item    100 non-null    int64
#  6   Order_Placed  100 non-null    float64
#  7   Revenue       100 non-null    int64
# dtypes: float64(1), int32(4), int64(3)
# memory usage: 4.8 KB

# %%
for col in df.columns:
    if df[col].dtypes!='object':
        plt.boxplot(df[col])
        plt.xlabel(col)
        plt.show()

# %%
cor =df.corr()

# %%
plt.figure(figsize =(15,10))
sns.heatmap(cor,annot = True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
X = df.drop(columns = 'Revenue')
y = df['Revenue']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train = sc.fit_transform(X_train)
x_test = sc.transform(X_test)

# %%
df
# Out:
#      Id  Name  Franchise  Category  City  No_Of_Item  Order_Placed  Revenue
# 0   101    40          1        12     0          55           5.5  5953753
# 1   102    14          0        19     1          72           6.8  7223131
# 2   103    16          1         5     4          25           1.9  2555379
# 3   104    60          1        11     2          18           2.5  2175511
# 4   105    68          1        13     3          48           4.2  4816715
# ..  ...   ...        ...       ...   ...         ...           ...      ...
# 95  196    96          0        11     0          19           1.1  1270499
# 96  197    47          1        19     0          75           6.3  6412623
# 97  198    35          1        19     1          77           6.2  6694797
# 98  199    41          1        17     4          25           2.1  2344689
# 99  200    55          0         2     2          50           4.4  4567678
#
# [100 rows x 8 columns]

# %%
x_train
# Out:
# array([[-0.69723101,  0.35223474, -1.05131497,  0.10608259, -0.96196538,
#         -0.46245115, -0.403858  ],
#        [ 1.14049808, -0.56472178, -1.05131497, -0.24752605,  0.38816147,
#          0.05377339,  0.73981067],
#        [ 1.10646606, -0.14151108,  0.95118973, -0.6011347 ,  1.73828831,
#         -0.03226403, -0.26089941],
#        [-0.22078273, -1.44641074, -1.05131497,  0.10608259, -0.96196538,
#         -0.72056342, -0.73742802],
#        [-0.73126303, -0.6352569 ,  0.95118973, -0.6011347 , -0.96196538,
#          0.22584824,  0.2156292 ],
#        [-0.93545515, -1.51694585,  0.95118973,  0.45969124,  1.06322489,
#         -0.20433888, -0.16559369],
#        [-0.90142313,  1.51606417, -1.05131497,  0.28288692,  0.38816147,
#         -0.54848857, -0.6421223 ],
#        [ 1.37872222, -0.77632713, -1.05131497, -0.6011347 , -0.96196538,
#         -0.41943244, -0.403858  ],
#        [ 1.24259414, -0.42365155,  0.95118973,  0.63649556,  1.06322489,
#         -0.41943244, -0.49916372],
#        [-1.00351919, -0.98793248,  0.95118973, -0.6011347 ,  1.06322489,
#          0.52697922,  0.59685208],
#        [-0.59513495, -0.67052445, -1.05131497, -1.30835199, -0.96196538,
#         -0.54848857, -0.49916372],
#        [-1.47996748, -1.12900271,  0.95118973,  1.16690853,  1.06322489,
#          0.35490437,  0.40624064],
#        [-1.58206354,  0.3875023 ,  0.95118973, -0.07072173,  0.38816147,
#         -1.36584409, -0.78508088],
#        [-1.27577536, -1.02320004,  0.95118973, -0.95474334, -0.96196538,
#         -1.19376925, -1.21395663],
#        [ 0.05147343, -1.65801609, -1.05131497,  0.28288692,  0.38816147,
#         -0.50546986, -0.49916372],
#        [ 1.1745301 ,  1.41026149,  0.95118973, -1.13154767,  1.06322489,
#          0.01075468, -0.11794083],
#        [ 0.80017787, -0.24731375, -1.05131497,  0.45969124,  1.73828831,
#         -0.46245115, -0.49916372],
#        [ 0.49388969,  0.77544544,  0.95118973,  1.34371286, -0.96196538,
#         -0.76358213, -0.83273375],
#        [ 0.15356949, -0.35311643,  0.95118973,  0.10608259,  1.06322489,
#          0.22584824,  0.16797634],
#        [ 0.63001777, -0.59998934,  0.95118973,  0.45969124,  1.06322489,
#         -0.24735759, -0.26089941],
#        [ 0.86824191,  1.69240196, -1.05131497, -1.48515631, -0.96196538,
#         -1.15075053, -1.16630377],
#        [ 0.11953747, -0.4589191 , -1.05131497,  1.16690853,  1.06322489,
#          0.48396051,  0.59685208],
#        [ 0.08550545,  0.70491032,  0.95118973, -0.6011347 ,  1.06322489,
#         -0.97867569, -1.21395663],
#        [-1.3438394 ,  1.30445882, -1.05131497, -0.42433038, -0.96196538,
#         -0.41943244, -0.26089941],
#        [-0.05062263,  1.72766952, -1.05131497,  1.34371286, -0.96196538,
#          1.9465967 ,  1.40695072],
#        [ 1.00436999,  1.48079661, -1.05131497,  1.34371286, -0.96196538,
#          0.8281102 ,  0.93042211],
#        [ 1.27662616,  0.28169962,  0.95118973,  1.34371286,  0.38816147,
#          0.74207277,  0.78746353],
#        [ 0.59598575,  1.16338858,  0.95118973,  1.16690853,  0.38816147,
#         -0.41943244, -0.16559369],
#        [-0.86739111,  0.95178323,  0.95118973, -1.66196064,  0.38816147,
#          2.59187737,  2.21704936],
#        [-1.41190344,  0.84598056,  0.95118973,  0.10608259,  0.38816147,
#          0.39792308,  0.31093492]])

# %%
y_train
# Out:
# 29    2447890
# 83    5966193
# 82    3807496
# 43    2732645
# 28    7705945
#        ...
# 79    6313221
# 87    5906596
# 67    4052733
# 24    7904084
# 8     5152497
# Name: Revenue, Length: 80, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf  = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_pred = rf.predict(x_test)

# %%
from sklearn.metrics import *

# %%
result = r2_score(y_test,rf_pred)

# %%
result
# Out:
# 0.8796376950857208

# %%
from sklearn.linear_model import LinearRegression

# %%
my_model = LinearRegression()

# %%
my_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = my_model.predict(x_test)

# %%
y_pred
# Out:
# array([2897476.79395679, 6008036.4523979 , 1692496.24573735,
#        4628584.9806481 , 4139629.80926891, 3408619.26971558,
#        2765384.89111863, 2046390.1698694 , 1470716.5633595 ,
#        -484484.05542758, 8125732.3877223 , 2116603.36214277,
#        7687499.2145729 , 3030574.64047603, 7149822.97265537,
#        4132144.34841007, 2747307.86143388, 5489961.34508231,
#        7906030.42907693, 6040434.00061403])

# %%
y_test
# Out:
# 37    2740687
# 62    5286212
# 26    2967425
# 41    4554237
# 35    3903884
# 25    2778621
# 36    3028267
# 33    2371202
# 77    1904842
# 21     849870
# 85    7495092
# 50    2156098
# 92    6782425
# 69    3452382
# 96    6412623
# 78    3871344
# 72    2525375
# 5     4517319
# 40    6836483
# 11    3861370
# Name: Revenue, dtype: int64

# %%
from sklearn.metrics import *

# %%
result = r2_score(y_test,y_pred)

# %%
result
# Out:
# 0.7860408140163758

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtc = DecisionTreeRegressor()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dtc.predict(x_test)

# %%
result = r2_score(y_test,y_pred)
result
# Out:
# 0.8235161956381365
